# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
from scipy.fft import fft, fftfreq
from scipy.signal import convolve as sig_convolve

# %%
ecgr = pd.read_csv("ecgr.txt")
ecgr =ecgr['values'].values
fig=plt.figure(figsize=(10,4))
plt.plot(ecgr[0:500])
plt.show()
print(np.mean(ecgr))
# Out:
# 0.08157175948831218

# %%
Fs = 200
T = 1 / Fs
N =len(ecgr)
xf = fftfreq(N, T)
xf= np.fft.fftshift(xf)

ecgr_fourier = np.fft.fft(ecgr[:])
ecgrf_shift = np.fft.fftshift(ecgr_fourier)
fig=plt.figure(figsize=(15,4))
plt.plot(xf,np.abs(ecgrf_shift))

print(np.abs(ecgr_fourier[0])/N)
# Out:
# (-40.22280745252427-43.4727139393467j)
# 0.08157175948831216

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
from scipy.fft import fft, fftfreq
from scipy.signal import kaiserord, lfilter, firwin, freqz
from scipy.signal import convolve as sig_convolve

# %%
ecgr = pd.read_csv("ecgr.txt")
ecgr =ecgr['values'].values
coef = pd.read_csv("coeficientes.csv")
coef =coef['coef'].values
fig=plt.figure(figsize=(10,4))
plt.plot(ecgr[0:300])
plt.show()
print(ecgr.shape)
# Out:
# (5433,)

# %%
coef = pd.read_csv("coeficientes.csv")
coef =coef['coef'].values
plt.plot(coef)

# %%
Fs = 200
T = 1 / Fs
N=len(coef)
xf2 = fftfreq(N, T)
xf2= np.fft.fftshift(xf2)

coef_fourier = np.fft.fft(coef[:])
coef_shift = np.fft.fftshift(coef_fourier)
fig=plt.figure(figsize=(15,4))
plt.plot(xf2,400*np.abs(coef_shift))
plt.plot(xf,np.abs(ecgrf_shift))
print(print(N))
# Out:
# 58
# None

# %%
conv_result= sig_convolve(ecgr, coef, mode='valid')
plt.plot(conv_result[0:600])
# plt.plot(ecgr[50:650])

# %%
print(coef.shape)
# Out:
# (58,)
